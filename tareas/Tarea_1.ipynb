# %% [markdown]
# <a href="https://colab.research.google.com/github/albertobenavides/prueba/blob/main/tareas/Tarea_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
r_sq
# Out:
# 0.7158756137479542

# %%
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: 5.633333333333329
# slope: [0.54]
